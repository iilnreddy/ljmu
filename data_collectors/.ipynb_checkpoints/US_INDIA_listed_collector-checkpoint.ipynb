# %% [markdown]
# # Key Features
# #### Dynamic NIFTY CSV parsing → avoids ParserError.
# #### Dow Jones handled separately via Wikipedia API.
# #### Multi-index tagging → symbols in multiple indices are combined with |.
# #### Deduplication → keeps one row per (Stock Symbol, Stock Market).
# #### Simple, maintainable structure — easy to extend for ISIN, sector, country later.

# %%
import pandas as pd
import yfinance as yf
from pathlib import Path
from datetime import datetime, timedelta
import time

# =========================
# Paths
# =========================
INPUT_FILE = Path("../Data/normalized_csv/ALL_INDEX_STOCKS.csv")
OUTPUT_DIR = Path("../Data/stock_ohlcv")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# =========================
# Read and deduplicate
# =========================
try:
    df = pd.read_csv(INPUT_FILE)
    df = df.drop_duplicates(subset=["Stock Symbol", "Stock Market"])
    print(f"Total unique stocks: {len(df)}")
except Exception as e:
        print(f"❌ Failed to read from {INPUT_FILE}: {e}")
    
# =========================
# Function to get Yahoo ticker
# =========================
def get_yahoo_ticker(symbol, market):
    if market.upper() == "NSE":
        return f"{symbol}.NS"
    elif market.upper() == "BSE":
        return f"{symbol}.BO"
    else:
        return symbol

# =========================
# Download OHLCV
# =========================
start_date = datetime.now() - timedelta(days=50*365)
end_date = datetime.now()

for idx, row in df.iterrows():
    symbol = row["Stock Symbol"]
    market = row["Stock Market"]
    name = row["Stock Name"]

    ticker = get_yahoo_ticker(symbol, market)
    out_file = OUTPUT_DIR / f"{symbol}_{market}.csv"

    try:
        print(f"Downloading {symbol} ({market}) ...")
        # data = yf.download(ticker, start=start_date, end=end_date, progress=False)
        data = yf.download(ticker, start=start_date, end=end_date, progress=False, auto_adjust=False)

        if data.empty:
            print(f"⚠️ No data for {symbol} ({market})")
            continue
        # Save CSV
        data.to_csv(out_file)
        print(f"✅ Saved → {out_file}")
        time.sleep(1)  # polite delay
    except Exception as e:
        print(f"❌ Failed for {symbol} ({market}): {e}")
# Out:
# Total unique stocks: 9179
# Downloading 360ONE (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\360ONE_NSE.csv
# Downloading 3MINDIA (NSE) ...
# 1 Failed download:
# ['3MINDIA.NS']: Timeout('Failed to perform, curl: (28) Operation timed out after 10002 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for 3MINDIA (NSE)
# Downloading A (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\A_NYSE.csv
# Downloading A (NYSE/NASDAQ) ...
# ❌ Failed for A (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\A_NYSE'
# Downloading AA (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AA_NYSE.csv
# Downloading AACB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AACB_NASDAQ.csv
# Downloading AACBR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AACBR_NASDAQ.csv
# Downloading AACBU (NASDAQ) ...
# 1 Failed download:
# ['AACBU']: Timeout('Failed to perform, curl: (28) Connection timed out after 10012 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AACBU (NASDAQ)
# Downloading AACG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AACG_NASDAQ.csv
# Downloading AADHARHFC (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AADHARHFC_NSE.csv
# Downloading AADR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AADR_NASDAQ.csv
# Downloading AAEQ (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAEQ_NASDAQ.csv
# Downloading AAL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAL_NASDAQ.csv
# Downloading AALG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AALG_NASDAQ.csv
# Downloading AAM (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAM_NYSE.csv
# Downloading AAM.U (NYSE) ...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: AAM.U"}}}
#
# 1 Failed download:
# ['AAM.U']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AAM.U (NYSE)
# Downloading AAM.W (NYSE) ...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: AAM.W"}}}
#
# 1 Failed download:
# ['AAM.W']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AAM.W (NYSE)
# Downloading AAME (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAME_NASDAQ.csv
# Downloading AAMI (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAMI_NYSE.csv
# Downloading AAOI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAOI_NASDAQ.csv
# Downloading AAON (NASDAQ) ...
# 1 Failed download:
# ['AAON']: Timeout('Failed to perform, curl: (28) Operation timed out after 10014 milliseconds with 203055 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AAON (NASDAQ)
# Downloading AAP (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAP_NYSE.csv
# Downloading AAPB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAPB_NASDAQ.csv
# Downloading AAPD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAPD_NASDAQ.csv
# Downloading AAPG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAPG_NASDAQ.csv
# Downloading AAPL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAPL_NASDAQ.csv
# Downloading AAPL (NYSE/NASDAQ) ...
# ❌ Failed for AAPL (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AAPL_NYSE'
# Downloading AAPU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAPU_NASDAQ.csv
# Downloading AARD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AARD_NASDAQ.csv
# Downloading AARTIIND (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AARTIIND_NSE.csv
# Downloading AAT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAT_NYSE.csv
# Downloading AAUC (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAUC_NYSE.csv
# Downloading AAUS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAUS_NASDAQ.csv
# Downloading AAVAS (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAVAS_NSE.csv
# Downloading AAVM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAVM_NASDAQ.csv
# Downloading AAXJ (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AAXJ_NASDAQ.csv
# Downloading AB (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AB_NYSE.csv
# Downloading ABAT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABAT_NASDAQ.csv
# Downloading ABB (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABB_NSE.csv
# Downloading ABBOTINDIA (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABBOTINDIA_NSE.csv
# Downloading ABBV (NYSE) ...
# 1 Failed download:
# ['ABBV']: Timeout('Failed to perform, curl: (28) Operation timed out after 10008 milliseconds with 41855 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ABBV (NYSE)
# Downloading ABBV (NYSE/NASDAQ) ...
# ❌ Failed for ABBV (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ABBV_NYSE'
# Downloading ABCAPITAL (NSE) ...
# 1 Failed download:
# ['ABCAPITAL.NS']: Timeout('Failed to perform, curl: (28) Connection timed out after 10004 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ABCAPITAL (NSE)
# Downloading ABCB (NYSE) ...
# 1 Failed download:
# ['ABCB']: Timeout('Failed to perform, curl: (28) Operation timed out after 10008 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ABCB (NYSE)
# Downloading ABCL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABCL_NASDAQ.csv
# Downloading ABCS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABCS_NASDAQ.csv
# Downloading ABEO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABEO_NASDAQ.csv
# Downloading ABEV (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABEV_NYSE.csv
# Downloading ABFRL (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABFRL_NSE.csv
# Downloading ABG (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABG_NYSE.csv
# Downloading ABI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABI_NASDAQ.csv
# Downloading ABIG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABIG_NASDAQ.csv
# Downloading ABLBL (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABLBL_NSE.csv
# Downloading ABLV (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABLV_NASDAQ.csv
# Downloading ABLVW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABLVW_NASDAQ.csv
# Downloading ABM (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABM_NYSE.csv
# Downloading ABNB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABNB_NASDAQ.csv
# Downloading ABNB (NYSE/NASDAQ) ...
# ❌ Failed for ABNB (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ABNB_NYSE'
# Downloading ABNG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABNG_NASDAQ.csv
# Downloading ABOS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABOS_NASDAQ.csv
# Downloading ABP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABP_NASDAQ.csv
# Downloading ABPWW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABPWW_NASDAQ.csv
# Downloading ABR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABR_NYSE.csv
# Downloading ABR$D (NYSE) ...
# Failed to get ticker 'ABR$D' reason: Failed to perform, curl: (28) Recv failure: Connection was reset. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 1 Failed download:
# ['ABR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ABR$D (NYSE)
# Downloading ABR$E (NYSE) ...
# 1 Failed download:
# ['ABR$E']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ABR$E (NYSE)
# Downloading ABR$F (NYSE) ...
# 1 Failed download:
# ['ABR$F']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ABR$F (NYSE)
# Downloading ABREL (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABREL_NSE.csv
# Downloading ABSI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABSI_NASDAQ.csv
# Downloading ABSLAMC (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABSLAMC_NSE.csv
# Downloading ABT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABT_NYSE.csv
# Downloading ABT (NYSE/NASDAQ) ...
# ❌ Failed for ABT (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ABT_NYSE'
# Downloading ABTC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABTC_NASDAQ.csv
# Downloading ABTS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABTS_NASDAQ.csv
# Downloading ABUS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABUS_NASDAQ.csv
# Downloading ABVC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABVC_NASDAQ.csv
# Downloading ABVE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABVE_NASDAQ.csv
# Downloading ABVEW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABVEW_NASDAQ.csv
# Downloading ABVX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABVX_NASDAQ.csv
# Downloading ABX (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABX_NYSE.csv
# Downloading ABXL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ABXL_NYSE.csv
# Downloading ACA (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACA_NYSE.csv
# Downloading ACAD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACAD_NASDAQ.csv
# Downloading ACB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACB_NASDAQ.csv
# Downloading ACC (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACC_NSE.csv
# Downloading ACCL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACCL_NASDAQ.csv
# Downloading ACCO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACCO_NYSE.csv
# Downloading ACDC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACDC_NASDAQ.csv
# Downloading ACE (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACE_NSE.csv
# Downloading ACEL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACEL_NYSE.csv
# Downloading ACEP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACEP_NASDAQ.csv
# Downloading ACET (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACET_NASDAQ.csv
# Downloading ACFN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACFN_NASDAQ.csv
# Downloading ACGL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACGL_NASDAQ.csv
# Downloading ACGL (NYSE/NASDAQ) ...
# ❌ Failed for ACGL (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ACGL_NYSE'
# Downloading ACGLN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACGLN_NASDAQ.csv
# Downloading ACGLO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACGLO_NASDAQ.csv
# Downloading ACH (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACH_NYSE.csv
# Downloading ACHC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACHC_NASDAQ.csv
# Downloading ACHR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACHR_NYSE.csv
# Downloading ACHR.W (NYSE) ...
# 1 Failed download:
# ['ACHR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ACHR.W (NYSE)
# Downloading ACHV (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACHV_NASDAQ.csv
# Downloading ACI (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACI_NYSE.csv
# Downloading ACIC (NASDAQ) ...
# 1 Failed download:
# ['ACIC']: Timeout('Failed to perform, curl: (28) Connection timed out after 10007 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ACIC (NASDAQ)
# Downloading ACIU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACIU_NASDAQ.csv
# Downloading ACIW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACIW_NASDAQ.csv
# Downloading ACLO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACLO_NYSE.csv
# Downloading ACLS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACLS_NASDAQ.csv
# Downloading ACLX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACLX_NASDAQ.csv
# Downloading ACM (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACM_NYSE.csv
# Downloading ACMESOLAR (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACMESOLAR_NSE.csv
# Downloading ACMR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACMR_NASDAQ.csv
# Downloading ACN (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACN_NYSE.csv
# Downloading ACN (NYSE/NASDAQ) ...
# ❌ Failed for ACN (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ACN_NYSE'
# Downloading ACNB (NASDAQ) ...
# 1 Failed download:
# ['ACNB']: Timeout('Failed to perform, curl: (28) Connection timed out after 10011 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ACNB (NASDAQ)
# Downloading ACNT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACNT_NASDAQ.csv
# Downloading ACOG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACOG_NASDAQ.csv
# Downloading ACON (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACON_NASDAQ.csv
# Downloading ACONW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACONW_NASDAQ.csv
# Downloading ACP (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACP_NYSE.csv
# Downloading ACP$A (NYSE) ...
# 1 Failed download:
# ['ACP$A']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ACP$A (NYSE)
# Downloading ACR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACR_NYSE.csv
# Downloading ACR$C (NYSE) ...
# 1 Failed download:
# ['ACR$C']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ACR$C (NYSE)
# Downloading ACR$D (NYSE) ...
# 1 Failed download:
# ['ACR$D']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ACR$D (NYSE)
# Downloading ACRE (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACRE_NYSE.csv
# Downloading ACRS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACRS_NASDAQ.csv
# Downloading ACRV (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACRV_NASDAQ.csv
# Downloading ACT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACT_NASDAQ.csv
# Downloading ACTG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACTG_NASDAQ.csv
# Downloading ACTU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACTU_NASDAQ.csv
# Downloading ACV (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACV_NYSE.csv
# Downloading ACVA (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACVA_NYSE.csv
# Downloading ACWI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACWI_NASDAQ.csv
# Downloading ACWX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACWX_NASDAQ.csv
# Downloading ACXP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ACXP_NASDAQ.csv
# Downloading AD (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AD_NYSE.csv
# Downloading ADACU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADACU_NASDAQ.csv
# Downloading ADAG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAG_NASDAQ.csv
# Downloading ADAM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAM_NASDAQ.csv
# Downloading ADAMG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAMG_NASDAQ.csv
# Downloading ADAMH (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAMH_NASDAQ.csv
# Downloading ADAMI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAMI_NASDAQ.csv
# Downloading ADAML (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAML_NASDAQ.csv
# Downloading ADAMM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAMM_NASDAQ.csv
# Downloading ADAMN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAMN_NASDAQ.csv
# Downloading ADAMO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAMO_NASDAQ.csv
# Downloading ADAMZ (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADAMZ_NASDAQ.csv
# Downloading ADANIENSOL (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADANIENSOL_NSE.csv
# Downloading ADANIENT (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADANIENT_NSE.csv
# Downloading ADANIGREEN (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADANIGREEN_NSE.csv
# Downloading ADANIPORTS (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADANIPORTS_NSE.csv
# Downloading ADANIPOWER (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADANIPOWER_NSE.csv
# Downloading ADBE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADBE_NASDAQ.csv
# Downloading ADBE (NYSE/NASDAQ) ...
# ❌ Failed for ADBE (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ADBE_NYSE'
# Downloading ADBG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADBG_NASDAQ.csv
# Downloading ADC (NYSE) ...
# 1 Failed download:
# ['ADC']: Timeout('Failed to perform, curl: (28) Operation timed out after 10015 milliseconds with 38088 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ADC (NYSE)
# Downloading ADC$A (NYSE) ...
# 1 Failed download:
# ['ADC$A']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ADC$A (NYSE)
# Downloading ADCT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADCT_NYSE.csv
# Downloading ADEA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADEA_NASDAQ.csv
# Downloading ADGM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADGM_NASDAQ.csv
# Downloading ADI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADI_NASDAQ.csv
# Downloading ADI (NYSE/NASDAQ) ...
# ❌ Failed for ADI (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ADI_NYSE'
# Downloading ADIL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADIL_NASDAQ.csv
# Downloading ADM (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADM_NYSE.csv
# Downloading ADM (NYSE/NASDAQ) ...
# ❌ Failed for ADM (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ADM_NYSE'
# Downloading ADMA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADMA_NASDAQ.csv
# Downloading ADNT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADNT_NYSE.csv
# Downloading ADP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADP_NASDAQ.csv
# Downloading ADP (NYSE/NASDAQ) ...
# 1 Failed download:
# ['ADP']: Timeout('Failed to perform, curl: (28) Operation timed out after 10013 milliseconds with 58755 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ADP (NYSE/NASDAQ)
# Downloading ADPT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADPT_NASDAQ.csv
# Downloading ADSE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADSE_NASDAQ.csv
# Downloading ADSEW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADSEW_NASDAQ.csv
# Downloading ADSK (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADSK_NASDAQ.csv
# Downloading ADSK (NYSE/NASDAQ) ...
# ❌ Failed for ADSK (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ADSK_NYSE'
# Downloading ADT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADT_NYSE.csv
# Downloading ADTN (NASDAQ) ...
# 1 Failed download:
# ['ADTN']: Timeout('Failed to perform, curl: (28) Connection timed out after 10016 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ADTN (NASDAQ)
# Downloading ADTX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADTX_NASDAQ.csv
# Downloading ADUR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADUR_NASDAQ.csv
# Downloading ADUS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADUS_NASDAQ.csv
# Downloading ADV (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADV_NASDAQ.csv
# Downloading ADVB (NASDAQ) ...
# 1 Failed download:
# ['ADVB']: Timeout('Failed to perform, curl: (28) Operation timed out after 10001 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ADVB (NASDAQ)
# Downloading ADX (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADX_NYSE.csv
# Downloading ADXN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ADXN_NASDAQ.csv
# Downloading AEAQ (NASDAQ) ...
# Failed to get ticker 'AEAQ' reason: Failed to perform, curl: (28) Connection timed out after 10006 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 1 Failed download:
# ['AEAQ']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AEAQ (NASDAQ)
# Downloading AEAQU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEAQU_NASDAQ.csv
# Downloading AEAQW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEAQW_NASDAQ.csv
# Downloading AEBI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEBI_NASDAQ.csv
# Downloading AEC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEC_NASDAQ.csv
# Downloading AEE (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEE_NYSE.csv
# Downloading AEE (NYSE/NASDAQ) ...
# ❌ Failed for AEE (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AEE_NYSE'
# Downloading AEFC (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEFC_NYSE.csv
# Downloading AEG (NYSE) ...
# 1 Failed download:
# ['AEG']: Timeout('Failed to perform, curl: (28) Operation timed out after 10002 milliseconds with 208264 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AEG (NYSE)
# Downloading AEGISLOG (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEGISLOG_NSE.csv
# Downloading AEGISVOPAK (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEGISVOPAK_NSE.csv
# Downloading AEHL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEHL_NASDAQ.csv
# Downloading AEHR (NASDAQ) ...
# 1 Failed download:
# ['AEHR']: Timeout('Failed to perform, curl: (28) Operation timed out after 10003 milliseconds with 82506 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AEHR (NASDAQ)
# Downloading AEI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEI_NASDAQ.csv
# Downloading AEIS (NASDAQ) ...
# 1 Failed download:
# ['AEIS']: Timeout('Failed to perform, curl: (28) Operation timed out after 10009 milliseconds with 162294 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AEIS (NASDAQ)
# Downloading AEM (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEM_NYSE.csv
# Downloading AEMD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEMD_NASDAQ.csv
# Downloading AENT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AENT_NASDAQ.csv
# Downloading AENTW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AENTW_NASDAQ.csv
# Downloading AEO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEO_NYSE.csv
# Downloading AEP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEP_NASDAQ.csv
# Downloading AEP (NYSE/NASDAQ) ...
# ❌ Failed for AEP (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AEP_NYSE'
# Downloading AER (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AER_NYSE.csv
# Downloading AERO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AERO_NYSE.csv
# Downloading AERT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AERT_NASDAQ.csv
# Downloading AERTW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AERTW_NASDAQ.csv
# Downloading AES (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AES_NYSE.csv
# Downloading AES (NYSE/NASDAQ) ...
# ❌ Failed for AES (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AES_NYSE'
# Downloading AESI (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AESI_NYSE.csv
# Downloading AEVA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEVA_NASDAQ.csv
# Downloading AEVAW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEVAW_NASDAQ.csv
# Downloading AEXA (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEXA_NYSE.csv
# Downloading AEYE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AEYE_NASDAQ.csv
# Downloading AFB (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFB_NYSE.csv
# Downloading AFBI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFBI_NASDAQ.csv
# Downloading AFCG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFCG_NASDAQ.csv
# Downloading AFCONS (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFCONS_NSE.csv
# Downloading AFFLE (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFFLE_NSE.csv
# Downloading AFG (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFG_NYSE.csv
# Downloading AFGB (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFGB_NYSE.csv
# Downloading AFGC (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFGC_NYSE.csv
# Downloading AFGD (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFGD_NYSE.csv
# Downloading AFGE (NYSE) ...
# 1 Failed download:
# ['AFGE']: Timeout('Failed to perform, curl: (28) Connection timed out after 10011 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AFGE (NYSE)
# Downloading AFJK (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFJK_NASDAQ.csv
# Downloading AFJKR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFJKR_NASDAQ.csv
# Downloading AFJKU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFJKU_NASDAQ.csv
# Downloading AFL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFL_NYSE.csv
# Downloading AFL (NYSE/NASDAQ) ...
# ❌ Failed for AFL (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AFL_NYSE'
# Downloading AFOS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFOS_NASDAQ.csv
# Downloading AFRI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFRI_NASDAQ.csv
# Downloading AFRIW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFRIW_NASDAQ.csv
# Downloading AFRM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFRM_NASDAQ.csv
# Downloading AFSC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFSC_NASDAQ.csv
# Downloading AFYA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AFYA_NASDAQ.csv
# Downloading AG (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AG_NYSE.csv
# Downloading AGAE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGAE_NASDAQ.csv
# Downloading AGARWALEYE (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGARWALEYE_NSE.csv
# Downloading AGCC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGCC_NASDAQ.csv
# Downloading AGCO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGCO_NYSE.csv
# Downloading AGD (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGD_NYSE.csv
# Downloading AGEM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGEM_NASDAQ.csv
# Downloading AGEN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGEN_NASDAQ.csv
# Downloading AGGA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGGA_NASDAQ.csv
# Downloading AGH (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGH_NASDAQ.csv
# Downloading AGI (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGI_NYSE.csv
# Downloading AGIO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGIO_NASDAQ.csv
# Downloading AGIX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGIX_NASDAQ.csv
# Downloading AGL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGL_NYSE.csv
# Downloading AGM (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGM_NYSE.csv
# Downloading AGM$D (NYSE) ...
# 1 Failed download:
# ['AGM$D']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AGM$D (NYSE)
# Downloading AGM$E (NYSE) ...
# 1 Failed download:
# ['AGM$E']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AGM$E (NYSE)
# Downloading AGM$F (NYSE) ...
# Failed to get ticker 'AGM$F' reason: Failed to perform, curl: (28) Operation timed out after 10002 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 1 Failed download:
# ['AGM$F']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AGM$F (NYSE)
# Downloading AGM$G (NYSE) ...
# 1 Failed download:
# ['AGM$G']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AGM$G (NYSE)
# Downloading AGM$H (NYSE) ...
# 1 Failed download:
# ['AGM$H']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AGM$H (NYSE)
# Downloading AGM.A (NYSE) ...
# 1 Failed download:
# ['AGM.A']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AGM.A (NYSE)
# Downloading AGMH (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGMH_NASDAQ.csv
# Downloading AGMI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGMI_NASDAQ.csv
# Downloading AGNC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGNC_NASDAQ.csv
# Downloading AGNCL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGNCL_NASDAQ.csv
# Downloading AGNCM (NASDAQ) ...
# 1 Failed download:
# ['AGNCM']: Timeout('Failed to perform, curl: (28) Connection timed out after 10010 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AGNCM (NASDAQ)
# Downloading AGNCN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGNCN_NASDAQ.csv
# Downloading AGNCO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGNCO_NASDAQ.csv
# Downloading AGNCP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGNCP_NASDAQ.csv
# Downloading AGNCZ (NASDAQ) ...
# 1 Failed download:
# ['AGNCZ']: Timeout('Failed to perform, curl: (28) Connection timed out after 10000 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AGNCZ (NASDAQ)
# Downloading AGNG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGNG_NASDAQ.csv
# Downloading AGO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGO_NYSE.csv
# Downloading AGPU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGPU_NASDAQ.csv
# Downloading AGRO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGRO_NYSE.csv
# Downloading AGRZ (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGRZ_NASDAQ.csv
# Downloading AGX (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGX_NYSE.csv
# Downloading AGYS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGYS_NASDAQ.csv
# Downloading AGZD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AGZD_NASDAQ.csv
# Downloading AHCO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AHCO_NASDAQ.csv
# Downloading AHG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AHG_NASDAQ.csv
# Downloading AHH (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AHH_NYSE.csv
# Downloading AHH$A (NYSE) ...
# 1 Failed download:
# ['AHH$A']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHH$A (NYSE)
# Downloading AHL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AHL_NYSE.csv
# Downloading AHL$D (NYSE) ...
# 1 Failed download:
# ['AHL$D']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHL$D (NYSE)
# Downloading AHL$E (NYSE) ...
# 1 Failed download:
# ['AHL$E']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHL$E (NYSE)
# Downloading AHL$F (NYSE) ...
# 1 Failed download:
# ['AHL$F']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHL$F (NYSE)
# Downloading AHMA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AHMA_NASDAQ.csv
# Downloading AHR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AHR_NYSE.csv
# Downloading AHT (NYSE) ...
# 1 Failed download:
# ['AHT']: Timeout('Failed to perform, curl: (28) Connection timed out after 10011 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AHT (NYSE)
# Downloading AHT$D (NYSE) ...
# 1 Failed download:
# ['AHT$D']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHT$D (NYSE)
# Downloading AHT$F (NYSE) ...
# 1 Failed download:
# ['AHT$F']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHT$F (NYSE)
# Downloading AHT$G (NYSE) ...
# 1 Failed download:
# ['AHT$G']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHT$G (NYSE)
# Downloading AHT$H (NYSE) ...
# 1 Failed download:
# ['AHT$H']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHT$H (NYSE)
# Downloading AHT$I (NYSE) ...
# 1 Failed download:
# ['AHT$I']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AHT$I (NYSE)
# Downloading AI (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AI_NYSE.csv
# Downloading AIA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIA_NASDAQ.csv
# Downloading AIAENG (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIAENG_NSE.csv
# Downloading AIFD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIFD_NASDAQ.csv
# Downloading AIFF (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIFF_NASDAQ.csv
# Downloading AIFU (NASDAQ) ...
# 1 Failed download:
# ['AIFU']: Timeout('Failed to perform, curl: (28) Connection timed out after 10012 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AIFU (NASDAQ)
# Downloading AIG (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIG_NYSE.csv
# Downloading AIG (NYSE/NASDAQ) ...
# ❌ Failed for AIG (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AIG_NYSE'
# Downloading AIHS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIHS_NASDAQ.csv
# Downloading AII (NYSE) ...
# 1 Failed download:
# ['AII']: Timeout('Failed to perform, curl: (28) Connection timed out after 10011 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AII (NYSE)
# Downloading AIIA (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIIA_NYSE.csv
# Downloading AIIA.R (NYSE) ...
# 1 Failed download:
# ['AIIA.R']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AIIA.R (NYSE)
# Downloading AIIA.U (NYSE) ...
# 1 Failed download:
# ['AIIA.U']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AIIA.U (NYSE)
# Downloading AIIL (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIIL_NSE.csv
# Downloading AIIO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIIO_NASDAQ.csv
# Downloading AIIOW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIIOW_NASDAQ.csv
# Downloading AIMD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIMD_NASDAQ.csv
# Downloading AIMDW (NASDAQ) ...
# 1 Failed download:
# ['AIMDW']: Timeout('Failed to perform, curl: (28) Connection timed out after 10005 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AIMDW (NASDAQ)
# Downloading AIN (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIN_NYSE.csv
# Downloading AIO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIO_NYSE.csv
# Downloading AIOT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIOT_NASDAQ.csv
# Downloading AIP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIP_NASDAQ.csv
# Downloading AIPI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIPI_NASDAQ.csv
# Downloading AIPO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIPO_NASDAQ.csv
# Downloading AIQ (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIQ_NASDAQ.csv
# Downloading AIR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIR_NYSE.csv
# Downloading AIRE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRE_NASDAQ.csv
# Downloading AIRG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRG_NASDAQ.csv
# Downloading AIRJ (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRJ_NASDAQ.csv
# Downloading AIRJW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRJW_NASDAQ.csv
# Downloading AIRO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRO_NASDAQ.csv
# Downloading AIRR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRR_NASDAQ.csv
# Downloading AIRS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRS_NASDAQ.csv
# Downloading AIRT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRT_NASDAQ.csv
# Downloading AIRTP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIRTP_NASDAQ.csv
# Downloading AISP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AISP_NASDAQ.csv
# Downloading AISPW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AISPW_NASDAQ.csv
# Downloading AIT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIT_NYSE.csv
# Downloading AIV (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIV_NYSE.csv
# Downloading AIXC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIXC_NASDAQ.csv
# Downloading AIXI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIXI_NASDAQ.csv
# Downloading AIZ (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIZ_NYSE.csv
# Downloading AIZ (NYSE/NASDAQ) ...
# ❌ Failed for AIZ (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AIZ_NYSE'
# Downloading AIZN (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AIZN_NYSE.csv
# Downloading AJANTPHARM (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AJANTPHARM_NSE.csv
# Downloading AJG (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AJG_NYSE.csv
# Downloading AJG (NYSE/NASDAQ) ...
# ❌ Failed for AJG (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AJG_NYSE'
# Downloading AKA (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKA_NYSE.csv
# Downloading AKAF (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKAF_NYSE.csv
# Downloading AKAM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKAM_NASDAQ.csv
# Downloading AKAM (NYSE/NASDAQ) ...
# ❌ Failed for AKAM (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AKAM_NYSE'
# Downloading AKAN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKAN_NASDAQ.csv
# Downloading AKBA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKBA_NASDAQ.csv
# Downloading AKO.A (NYSE) ...
# 1 Failed download:
# ['AKO.A']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AKO.A (NYSE)
# Downloading AKO.B (NYSE) ...
# 1 Failed download:
# ['AKO.B']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AKO.B (NYSE)
# Downloading AKR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKR_NYSE.csv
# Downloading AKTS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKTS_NASDAQ.csv
# Downloading AKTX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKTX_NASDAQ.csv
# Downloading AKUMS (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKUMS_NSE.csv
# Downloading AKZOINDIA (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AKZOINDIA_NSE.csv
# Downloading AL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AL_NYSE.csv
# Downloading ALAB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALAB_NASDAQ.csv
# Downloading ALAR (NASDAQ) ...
# 1 Failed download:
# ['ALAR']: Timeout('Failed to perform, curl: (28) Connection timed out after 10003 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ALAR (NASDAQ)
# Downloading ALB (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALB_NYSE.csv
# Downloading ALB (NYSE/NASDAQ) ...
# ❌ Failed for ALB (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ALB_NYSE'
# Downloading ALB$A (NYSE) ...
# 1 Failed download:
# ['ALB$A']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALB$A (NYSE)
# Downloading ALBG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALBG_NASDAQ.csv
# Downloading ALBT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALBT_NASDAQ.csv
# Downloading ALC (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALC_NYSE.csv
# Downloading ALCO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALCO_NASDAQ.csv
# Downloading ALCY (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALCY_NASDAQ.csv
# Downloading ALCYU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALCYU_NASDAQ.csv
# Downloading ALCYW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALCYW_NASDAQ.csv
# Downloading ALDF (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALDF_NASDAQ.csv
# Downloading ALDFU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALDFU_NASDAQ.csv
# Downloading ALDFW (NASDAQ) ...
# 1 Failed download:
# ['ALDFW']: Timeout('Failed to perform, curl: (28) Operation timed out after 10002 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ALDFW (NASDAQ)
# Downloading ALDX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALDX_NASDAQ.csv
# Downloading ALEC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALEC_NASDAQ.csv
# Downloading ALEX (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALEX_NYSE.csv
# Downloading ALF (NASDAQ) ...
# 1 Failed download:
# ['ALF']: Timeout('Failed to perform, curl: (28) Connection timed out after 10011 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for ALF (NASDAQ)
# Downloading ALFUU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALFUU_NASDAQ.csv
# Downloading ALFUW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALFUW_NASDAQ.csv
# Downloading ALG (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALG_NYSE.csv
# Downloading ALGM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALGM_NASDAQ.csv
# Downloading ALGN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALGN_NASDAQ.csv
# Downloading ALGN (NYSE/NASDAQ) ...
# ❌ Failed for ALGN (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ALGN_NYSE'
# Downloading ALGS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALGS_NASDAQ.csv
# Downloading ALGT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALGT_NASDAQ.csv
# Downloading ALH (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALH_NYSE.csv
# Downloading ALHC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALHC_NASDAQ.csv
# Downloading ALIL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALIL_NASDAQ.csv
# Downloading ALIS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALIS_NASDAQ.csv
# Downloading ALISR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALISR_NASDAQ.csv
# Downloading ALISU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALISU_NASDAQ.csv
# Downloading ALIT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALIT_NYSE.csv
# Downloading ALK (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALK_NYSE.csv
# Downloading ALKEM (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALKEM_NSE.csv
# Downloading ALKS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALKS_NASDAQ.csv
# Downloading ALKT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALKT_NASDAQ.csv
# Downloading ALKYLAMINE (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALKYLAMINE_NSE.csv
# Downloading ALL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALL_NYSE.csv
# Downloading ALL (NYSE/NASDAQ) ...
# ❌ Failed for ALL (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ALL_NYSE'
# Downloading ALL$B (NYSE) ...
# 1 Failed download:
# ['ALL$B']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALL$B (NYSE)
# Downloading ALL$H (NYSE) ...
# 1 Failed download:
# ['ALL$H']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALL$H (NYSE)
# Downloading ALL$I (NYSE) ...
# Failed to get ticker 'ALL$I' reason: Failed to perform, curl: (28) Connection timed out after 10004 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 1 Failed download:
# ['ALL$I']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALL$I (NYSE)
# Downloading ALL$J (NYSE) ...
# 1 Failed download:
# ['ALL$J']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALL$J (NYSE)
# Downloading ALLE (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALLE_NYSE.csv
# Downloading ALLE (NYSE/NASDAQ) ...
# ❌ Failed for ALLE (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\ALLE_NYSE'
# Downloading ALLO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALLO_NASDAQ.csv
# Downloading ALLR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALLR_NASDAQ.csv
# Downloading ALLT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALLT_NASDAQ.csv
# Downloading ALLW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALLW_NASDAQ.csv
# Downloading ALLY (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALLY_NYSE.csv
# Downloading ALM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALM_NASDAQ.csv
# Downloading ALMS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALMS_NASDAQ.csv
# Downloading ALMU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALMU_NASDAQ.csv
# Downloading ALNT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALNT_NASDAQ.csv
# Downloading ALNY (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALNY_NASDAQ.csv
# Downloading ALOKINDS (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALOKINDS_NSE.csv
# Downloading ALOT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALOT_NASDAQ.csv
# Downloading ALOVU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALOVU_NASDAQ.csv
# Downloading ALPS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALPS_NASDAQ.csv
# Downloading ALRM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALRM_NASDAQ.csv
# Downloading ALRS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALRS_NASDAQ.csv
# Downloading ALSN (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALSN_NYSE.csv
# Downloading ALT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALT_NASDAQ.csv
# Downloading ALTG (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALTG_NYSE.csv
# Downloading ALTG$A (NYSE) ...
# 1 Failed download:
# ['ALTG$A']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALTG$A (NYSE)
# Downloading ALTI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALTI_NASDAQ.csv
# Downloading ALTO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALTO_NASDAQ.csv
# Downloading ALTS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALTS_NASDAQ.csv
# Downloading ALTY (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALTY_NASDAQ.csv
# Downloading ALUB (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALUB_NYSE.csv
# Downloading ALUB.U (NYSE) ...
# 1 Failed download:
# ['ALUB.U']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALUB.U (NYSE)
# Downloading ALUB.W (NYSE) ...
# 1 Failed download:
# ['ALUB.W']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALUB.W (NYSE)
# Downloading ALUR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALUR_NYSE.csv
# Downloading ALUR.W (NYSE) ...
# 1 Failed download:
# ['ALUR.W']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for ALUR.W (NYSE)
# Downloading ALV (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALV_NYSE.csv
# Downloading ALVO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALVO_NASDAQ.csv
# Downloading ALVOW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALVOW_NASDAQ.csv
# Downloading ALX (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALX_NYSE.csv
# Downloading ALXO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALXO_NASDAQ.csv
# Downloading ALZN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\ALZN_NASDAQ.csv
# Downloading AM (NYSE) ...
# 1 Failed download:
# ['AM']: Timeout('Failed to perform, curl: (28) Operation timed out after 10013 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AM (NYSE)
# Downloading AMAL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMAL_NASDAQ.csv
# Downloading AMAT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMAT_NASDAQ.csv
# Downloading AMAT (NYSE/NASDAQ) ...
# 1 Failed download:
# ['AMAT']: Timeout('Failed to perform, curl: (28) Operation timed out after 10013 milliseconds with 238398 out of 264437 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AMAT (NYSE/NASDAQ)
# Downloading AMBA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMBA_NASDAQ.csv
# Downloading AMBER (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMBER_NSE.csv
# Downloading AMBP (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMBP_NYSE.csv
# Downloading AMBQ (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMBQ_NYSE.csv
# Downloading AMBR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMBR_NASDAQ.csv
# Downloading AMBUJACEM (NSE) ...
# 1 Failed download:
# ['AMBUJACEM.NS']: Timeout('Failed to perform, curl: (28) Operation timed out after 10012 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AMBUJACEM (NSE)
# Downloading AMC (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMC_NYSE.csv
# Downloading AMCI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMCI_NASDAQ.csv
# Downloading AMCR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMCR_NYSE.csv
# Downloading AMCR (NYSE/NASDAQ) ...
# ❌ Failed for AMCR (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AMCR_NYSE'
# Downloading AMCX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMCX_NASDAQ.csv
# Downloading AMD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMD_NASDAQ.csv
# Downloading AMD (NYSE/NASDAQ) ...
# ❌ Failed for AMD (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AMD_NYSE'
# Downloading AMDD (NASDAQ) ...
# 1 Failed download:
# ['AMDD']: Timeout('Failed to perform, curl: (28) Connection timed out after 10006 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AMDD (NASDAQ)
# Downloading AMDG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMDG_NASDAQ.csv
# Downloading AMDL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMDL_NASDAQ.csv
# Downloading AME (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AME_NYSE.csv
# Downloading AME (NYSE/NASDAQ) ...
# ❌ Failed for AME (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AME_NYSE'
# Downloading AMG (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMG_NYSE.csv
# Downloading AMGN (NASDAQ) ...
# 1 Failed download:
# ['AMGN']: Timeout('Failed to perform, curl: (28) Operation timed out after 10015 milliseconds with 120318 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AMGN (NASDAQ)
# Downloading AMGN (NYSE/NASDAQ) ...
# ❌ Failed for AMGN (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AMGN_NYSE'
# Downloading AMH (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMH_NYSE.csv
# Downloading AMH$G (NYSE) ...
# 1 Failed download:
# ['AMH$G']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AMH$G (NYSE)
# Downloading AMH$H (NYSE) ...
# 1 Failed download:
# ['AMH$H']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AMH$H (NYSE)
# Downloading AMID (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMID_NASDAQ.csv
# Downloading AMIX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMIX_NASDAQ.csv
# Downloading AMKR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMKR_NASDAQ.csv
# Downloading AMLX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMLX_NASDAQ.csv
# Downloading AMN (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMN_NYSE.csv
# Downloading AMOD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMOD_NASDAQ.csv
# Downloading AMODW (NASDAQ) ...
# 1 Failed download:
# ['AMODW']: Timeout('Failed to perform, curl: (28) Connection timed out after 10011 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AMODW (NASDAQ)
# Downloading AMP (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMP_NYSE.csv
# Downloading AMP (NYSE/NASDAQ) ...
# ❌ Failed for AMP (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\AMP_NYSE'
# Downloading AMPG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMPG_NASDAQ.csv
# Downloading AMPGW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMPGW_NASDAQ.csv
# Downloading AMPH (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMPH_NASDAQ.csv
# Downloading AMPL (NASDAQ) ...
# 1 Failed download:
# ['AMPL']: Timeout('Failed to perform, curl: (28) Connection timed out after 10016 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AMPL (NASDAQ)
# Downloading AMPX (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMPX_NYSE.csv
# Downloading AMPX.W (NYSE) ...
# 1 Failed download:
# ['AMPX.W']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for AMPX.W (NYSE)
# Downloading AMPY (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMPY_NYSE.csv
# Downloading AMR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMR_NYSE.csv
# Downloading AMRC (NYSE) ...
# 1 Failed download:
# ['AMRC']: Timeout('Failed to perform, curl: (28) Operation timed out after 10014 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for AMRC (NYSE)
# Downloading AMRN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\AMRN_NASDAQ.csv
# ...
# Downloading FLYE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FLYE_NASDAQ.csv
# Downloading FLYW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FLYW_NASDAQ.csv
# Downloading FMAO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMAO_NASDAQ.csv
# Downloading FMB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMB_NASDAQ.csv
# Downloading FMBH (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMBH_NASDAQ.csv
# Downloading FMC (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMC_NYSE.csv
# Downloading FMED (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMED_NASDAQ.csv
# Downloading FMET (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMET_NASDAQ.csv
# Downloading FMFC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMFC_NASDAQ.csv
# Downloading FMHI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMHI_NASDAQ.csv
# Downloading FMN (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMN_NYSE.csv
# Downloading FMNB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMNB_NASDAQ.csv
# Downloading FMS (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMS_NYSE.csv
# Downloading FMST (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMST_NASDAQ.csv
# Downloading FMSTW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMSTW_NASDAQ.csv
# Downloading FMTM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMTM_NASDAQ.csv
# Downloading FMUB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMUB_NASDAQ.csv
# Downloading FMUN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMUN_NASDAQ.csv
# Downloading FMX (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMX_NYSE.csv
# Downloading FMY (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FMY_NYSE.csv
# Downloading FN (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FN_NYSE.csv
# Downloading FNB (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNB_NYSE.csv
# Downloading FND (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FND_NYSE.csv
# Downloading FNF (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNF_NYSE.csv
# Downloading FNGR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNGR_NASDAQ.csv
# Downloading FNK (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNK_NASDAQ.csv
# Downloading FNKO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNKO_NASDAQ.csv
# Downloading FNLC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNLC_NASDAQ.csv
# Downloading FNV (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNV_NYSE.csv
# Downloading FNWB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNWB_NASDAQ.csv
# Downloading FNWD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNWD_NASDAQ.csv
# Downloading FNX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNX_NASDAQ.csv
# Downloading FNY (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FNY_NASDAQ.csv
# Downloading FOA (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOA_NYSE.csv
# Downloading FOF (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOF_NYSE.csv
# Downloading FOFO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOFO_NASDAQ.csv
# Downloading FOLD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOLD_NASDAQ.csv
# Downloading FONR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FONR_NASDAQ.csv
# Downloading FOR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOR_NYSE.csv
# Downloading FORA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FORA_NASDAQ.csv
# Downloading FORCEMOT (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FORCEMOT_NSE.csv
# Downloading FORM (NASDAQ) ...
# 1 Failed download:
# ['FORM']: Timeout('Failed to perform, curl: (28) Connection timed out after 10005 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for FORM (NASDAQ)
# Downloading FORR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FORR_NASDAQ.csv
# Downloading FORTIS (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FORTIS_NSE.csv
# Downloading FORTY (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FORTY_NASDAQ.csv
# Downloading FOSL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOSL_NASDAQ.csv
# Downloading FOUR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOUR_NYSE.csv
# Downloading FOUR$A (NYSE) ...
# 1 Failed download:
# ['FOUR$A']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for FOUR$A (NYSE)
# Downloading FOX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOX_NASDAQ.csv
# Downloading FOX (NYSE/NASDAQ) ...
# ❌ Failed for FOX (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\FOX_NYSE'
# Downloading FOXA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOXA_NASDAQ.csv
# Downloading FOXA (NYSE/NASDAQ) ...
# ❌ Failed for FOXA (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\FOXA_NYSE'
# Downloading FOXF (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOXF_NASDAQ.csv
# Downloading FOXX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOXX_NASDAQ.csv
# Downloading FOXXW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FOXXW_NASDAQ.csv
# Downloading FPA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FPA_NASDAQ.csv
# Downloading FPF (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FPF_NYSE.csv
# Downloading FPH (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FPH_NYSE.csv
# Downloading FPI (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FPI_NYSE.csv
# Downloading FPXE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FPXE_NASDAQ.csv
# Downloading FPXI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FPXI_NASDAQ.csv
# Downloading FR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FR_NYSE.csv
# Downloading FRA (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRA_NYSE.csv
# Downloading FRAF (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRAF_NASDAQ.csv
# Downloading FRBA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRBA_NASDAQ.csv
# Downloading FRD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRD_NASDAQ.csv
# Downloading FRDD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRDD_NASDAQ.csv
# Downloading FRDU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRDU_NASDAQ.csv
# Downloading FRGE (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRGE_NYSE.csv
# Downloading FRGT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRGT_NASDAQ.csv
# Downloading FRHC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRHC_NASDAQ.csv
# Downloading FRME (NASDAQ) ...
# 1 Failed download:
# ['FRME']: Timeout('Failed to perform, curl: (28) Operation timed out after 10013 milliseconds with 201583 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ⚠️ No data for FRME (NASDAQ)
# Downloading FRMEP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRMEP_NASDAQ.csv
# Downloading FRMI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRMI_NASDAQ.csv
# Downloading FRO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRO_NYSE.csv
# Downloading FROG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FROG_NASDAQ.csv
# Downloading FRPH (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRPH_NASDAQ.csv
# Downloading FRPT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRPT_NASDAQ.csv
# Downloading FRSH (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRSH_NASDAQ.csv
# Downloading FRST (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRST_NASDAQ.csv
# Downloading FRSX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRSX_NASDAQ.csv
# Downloading FRT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRT_NYSE.csv
# Downloading FRT (NYSE/NASDAQ) ...
# ❌ Failed for FRT (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\FRT_NYSE'
# Downloading FRT$C (NYSE) ...
# 1 Failed download:
# ['FRT$C']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for FRT$C (NYSE)
# Downloading FRWD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FRWD_NASDAQ.csv
# Downloading FSBC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSBC_NASDAQ.csv
# Downloading FSBW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSBW_NASDAQ.csv
# Downloading FSCO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSCO_NYSE.csv
# Downloading FSCS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSCS_NASDAQ.csv
# Downloading FSEA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSEA_NASDAQ.csv
# Downloading FSFG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSFG_NASDAQ.csv
# Downloading FSGS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSGS_NASDAQ.csv
# Downloading FSHP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSHP_NASDAQ.csv
# Downloading FSHPR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSHPR_NASDAQ.csv
# Downloading FSHPU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSHPU_NASDAQ.csv
# Downloading FSK (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSK_NYSE.csv
# Downloading FSL (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSL_NSE.csv
# Downloading FSLR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSLR_NASDAQ.csv
# Downloading FSLR (NYSE/NASDAQ) ...
# ❌ Failed for FSLR (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\FSLR_NYSE'
# Downloading FSLY (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSLY_NASDAQ.csv
# Downloading FSM (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSM_NYSE.csv
# Downloading FSS (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSS_NYSE.csv
# Downloading FSSL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSSL_NYSE.csv
# Downloading FSTR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSTR_NASDAQ.csv
# Downloading FSUN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSUN_NASDAQ.csv
# Downloading FSV (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSV_NASDAQ.csv
# Downloading FSZ (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FSZ_NASDAQ.csv
# Downloading FT (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FT_NYSE.csv
# Downloading FTA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTA_NASDAQ.csv
# Downloading FTAG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTAG_NASDAQ.csv
# Downloading FTAI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTAI_NASDAQ.csv
# Downloading FTAIM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTAIM_NASDAQ.csv
# Downloading FTAIN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTAIN_NASDAQ.csv
# Downloading FTC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTC_NASDAQ.csv
# Downloading FTCI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTCI_NASDAQ.csv
# Downloading FTCS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTCS_NASDAQ.csv
# Downloading FTDR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTDR_NASDAQ.csv
# Downloading FTDS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTDS_NASDAQ.csv
# Downloading FTEK (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTEK_NASDAQ.csv
# Downloading FTEL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTEL_NASDAQ.csv
# Downloading FTFT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTFT_NASDAQ.csv
# Downloading FTGC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTGC_NASDAQ.csv
# Downloading FTGS (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTGS_NASDAQ.csv
# Downloading FTHI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTHI_NASDAQ.csv
# Downloading FTHM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTHM_NASDAQ.csv
# Downloading FTHY (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTHY_NYSE.csv
# Downloading FTI (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTI_NYSE.csv
# Downloading FTK (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTK_NYSE.csv
# Downloading FTLF (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTLF_NASDAQ.csv
# Downloading FTNT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTNT_NASDAQ.csv
# Downloading FTNT (NYSE/NASDAQ) ...
# ❌ Failed for FTNT (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\FTNT_NYSE'
# Downloading FTQI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTQI_NASDAQ.csv
# Downloading FTRE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTRE_NASDAQ.csv
# Downloading FTRI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTRI_NASDAQ.csv
# Downloading FTRK (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTRK_NASDAQ.csv
# Downloading FTS (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTS_NYSE.csv
# Downloading FTSL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTSL_NASDAQ.csv
# Downloading FTSM (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTSM_NASDAQ.csv
# Downloading FTV (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTV_NYSE.csv
# Downloading FTV (NYSE/NASDAQ) ...
# ❌ Failed for FTV (NYSE/NASDAQ): Cannot save file into a non-existent directory: '..\Data\stock_ohlcv\FTV_NYSE'
# Downloading FTW (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTW_NYSE.csv
# Downloading FTW.U (NYSE) ...
# 1 Failed download:
# ['FTW.U']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for FTW.U (NYSE)
# Downloading FTW.W (NYSE) ...
# 1 Failed download:
# ['FTW.W']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for FTW.W (NYSE)
# Downloading FTWO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTWO_NYSE.csv
# Downloading FTXG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTXG_NASDAQ.csv
# Downloading FTXH (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTXH_NASDAQ.csv
# Downloading FTXL (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTXL_NASDAQ.csv
# Downloading FTXN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTXN_NASDAQ.csv
# Downloading FTXO (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTXO_NASDAQ.csv
# Downloading FTXR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FTXR_NASDAQ.csv
# Downloading FUBO (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUBO_NYSE.csv
# Downloading FUFU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUFU_NASDAQ.csv
# Downloading FUFUW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUFUW_NASDAQ.csv
# Downloading FUL (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUL_NYSE.csv
# Downloading FULC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FULC_NASDAQ.csv
# Downloading FULT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FULT_NASDAQ.csv
# Downloading FULTP (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FULTP_NASDAQ.csv
# Downloading FUN (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUN_NYSE.csv
# Downloading FUNC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUNC_NASDAQ.csv
# Downloading FUND (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUND_NASDAQ.csv
# Downloading FUSB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUSB_NASDAQ.csv
# Downloading FUSE (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUSE_NASDAQ.csv
# Downloading FUSEW (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUSEW_NASDAQ.csv
# Downloading FUTG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUTG_NASDAQ.csv
# Downloading FUTU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FUTU_NASDAQ.csv
# Downloading FV (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FV_NASDAQ.csv
# Downloading FVC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FVC_NASDAQ.csv
# Downloading FVCB (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FVCB_NASDAQ.csv
# Downloading FVN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FVN_NASDAQ.csv
# Downloading FVNNR (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FVNNR_NASDAQ.csv
# Downloading FVNNU (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FVNNU_NASDAQ.csv
# Downloading FVR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FVR_NYSE.csv
# Downloading FVRR (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FVRR_NYSE.csv
# Downloading FWDI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FWDI_NASDAQ.csv
# Downloading FWONA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FWONA_NASDAQ.csv
# Downloading FWONK (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FWONK_NASDAQ.csv
# Downloading FWRD (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FWRD_NASDAQ.csv
# Downloading FWRG (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FWRG_NASDAQ.csv
# Downloading FXED (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\FXED_NYSE.csv
# Downloading FXNC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FXNC_NASDAQ.csv
# Downloading FYC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FYC_NASDAQ.csv
# Downloading FYT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FYT_NASDAQ.csv
# Downloading FYX (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\FYX_NASDAQ.csv
# Downloading G (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\G_NYSE.csv
# Downloading GAB (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\GAB_NYSE.csv
# Downloading GAB$G (NYSE) ...
# 1 Failed download:
# ['GAB$G']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for GAB$G (NYSE)
# Downloading GAB$H (NYSE) ...
# 1 Failed download:
# ['GAB$H']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for GAB$H (NYSE)
# Downloading GAB$K (NYSE) ...
# 1 Failed download:
# ['GAB$K']: YFTzMissingError('possibly delisted; no timezone found')
# ⚠️ No data for GAB$K (NYSE)
# Downloading GABC (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\GABC_NASDAQ.csv
# Downloading GAIA (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\GAIA_NASDAQ.csv
# Downloading GAIL (NSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\GAIL_NSE.csv
# Downloading GAIN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\GAIN_NASDAQ.csv
# Downloading GAINI (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\GAINI_NASDAQ.csv
# Downloading GAINN (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\GAINN_NASDAQ.csv
# Downloading GAINZ (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\GAINZ_NASDAQ.csv
# Downloading GALT (NASDAQ) ...
# ✅ Saved → ..\Data\stock_ohlcv\GALT_NASDAQ.csv
# Downloading GAM (NYSE) ...
# ✅ Saved → ..\Data\stock_ohlcv\GAM_NYSE.csv
